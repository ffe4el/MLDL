# %%
import pandas as pd
import numpy as np

# 트레인셋
tr = pd.read_csv('/Users/sola/Downloads/open/train.csv')
tr
# Out:
#     PRODUCT_ID  Y_Class  Y_Quality         TIMESTAMP     LINE PRODUCT_CODE  \
# 0    TRAIN_000        1   0.533433   2022-06-13 5:14  T050304         A_31
# 1    TRAIN_001        2   0.541819   2022-06-13 5:22  T050307         A_31
# 2    TRAIN_002        1   0.531267   2022-06-13 5:30  T050304         A_31
# 3    TRAIN_003        2   0.537325   2022-06-13 5:39  T050307         A_31
# 4    TRAIN_004        1   0.531590   2022-06-13 5:47  T050304         A_31
# ..         ...      ...        ...               ...      ...          ...
# 593  TRAIN_593        1   0.526546  2022-09-08 14:30  T100306         T_31
# 594  TRAIN_594        0   0.524022  2022-09-08 22:38  T050304         A_31
# 595  TRAIN_595        0   0.521289  2022-09-08 22:47  T050304         A_31
# 596  TRAIN_596        1   0.531375  2022-09-08 14:38  T100304         O_31
# 597  TRAIN_597        1   0.533702  2022-09-08 14:46  T100306         O_31
#
# ...

# %%
# 테스트셋
ts = pd.read_csv('/Users/sola/Downloads/open/test.csv')
ts
# Out:
#     PRODUCT_ID         TIMESTAMP     LINE PRODUCT_CODE  X_1   X_2  X_3   X_4  \
# 0     TEST_000   2022-09-09 2:01  T100306         T_31  2.0  94.0  0.0  45.0
# 1     TEST_001   2022-09-09 2:09  T100304         T_31  2.0  93.0  0.0  45.0
# 2     TEST_002   2022-09-09 8:42  T100304         T_31  2.0  95.0  0.0  45.0
# 3     TEST_003  2022-09-09 10:56  T010305         A_31  NaN   NaN  NaN   NaN
# 4     TEST_004  2022-09-09 11:04  T010306         A_31  NaN   NaN  NaN   NaN
# ..         ...               ...      ...          ...  ...   ...  ...   ...
# 305   TEST_305  2022-11-05 11:18  T100306         T_31  2.0  91.0  0.0  45.0
# 306   TEST_306  2022-11-05 16:39  T100304         T_31  2.0  96.0  0.0  45.0
# 307   TEST_307  2022-11-05 16:47  T100306         T_31  2.0  91.0  0.0  45.0
# 308   TEST_308  2022-11-05 20:53  T100306         T_31  2.0  95.0  0.0  45.0
# 309   TEST_309  2022-11-05 21:01  T100306         T_31  2.0  87.0  0.0  45.0
#
# ...

# %%
tr.columns
# Out:
# Index(['PRODUCT_ID', 'Y_Class', 'Y_Quality', 'TIMESTAMP', 'LINE',
#        'PRODUCT_CODE', 'X_1', 'X_2', 'X_3', 'X_4',
#        ...
#        'X_2866', 'X_2867', 'X_2868', 'X_2869', 'X_2870', 'X_2871', 'X_2872',
#        'X_2873', 'X_2874', 'X_2875'],
#       dtype='object', length=2881)

# %%
x_columns = []
for i in range(1,2876):
    co = "X_" + str(i)
    x_columns.append(co)
    tr.loc[tr[co].isna(), co]= tr[co].mean()
# print(x_columns)
tr.head()
# Out:
#   PRODUCT_ID  Y_Class  Y_Quality        TIMESTAMP     LINE PRODUCT_CODE  \
# 0  TRAIN_000        1   0.533433  2022-06-13 5:14  T050304         A_31
# 1  TRAIN_001        2   0.541819  2022-06-13 5:22  T050307         A_31
# 2  TRAIN_002        1   0.531267  2022-06-13 5:30  T050304         A_31
# 3  TRAIN_003        2   0.537325  2022-06-13 5:39  T050307         A_31
# 4  TRAIN_004        1   0.531590  2022-06-13 5:47  T050304         A_31
#
#         X_1        X_2  X_3   X_4  ...  X_2866  X_2867  X_2868  X_2869  \
# 0  2.409742  95.123209  0.0  45.0  ...   39.34   40.89   32.56   34.09
# 1  2.409742  95.123209  0.0  45.0  ...   38.89   42.82   43.92   35.34
# 2  2.409742  95.123209  0.0  45.0  ...   39.19   36.65   42.47   36.53
# 3  2.409742  95.123209  0.0  45.0  ...   37.74   39.17   52.17   30.58
# 4  2.409742  95.123209  0.0  45.0  ...   38.70   41.89   46.93   33.09
#
#    X_2870  X_2871  X_2872  X_2873  X_2874  X_2875
# 0   77.77     1.0     NaN     NaN     NaN     NaN
# ...

# %%
tr["X_6"].mean()
# Out:
# 0.0

# %%
tr.isnull()
# Out:
#      PRODUCT_ID  Y_Class  Y_Quality  TIMESTAMP   LINE  PRODUCT_CODE    X_1  \
# 0         False    False      False      False  False         False  False
# 1         False    False      False      False  False         False  False
# 2         False    False      False      False  False         False  False
# 3         False    False      False      False  False         False  False
# 4         False    False      False      False  False         False  False
# ..          ...      ...        ...        ...    ...           ...    ...
# 593       False    False      False      False  False         False  False
# 594       False    False      False      False  False         False  False
# 595       False    False      False      False  False         False  False
# 596       False    False      False      False  False         False  False
# 597       False    False      False      False  False         False  False
#
# ...

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Columns: 2881 entries, PRODUCT_ID to X_2875
# dtypes: float64(2876), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
tr.describe()
# Out:
#           Y_Class   Y_Quality         X_1         X_2    X_3    X_4  \
# count  598.000000  598.000000  598.000000  598.000000  598.0  598.0
# mean     1.025084    0.530896    2.409742   95.123209    0.0   45.0
# std      0.565069    0.007401    4.500960    3.136136    0.0    0.0
# min      0.000000    0.500856    1.000000   87.000000    0.0   45.0
# 25%      1.000000    0.527535    2.000000   94.000000    0.0   45.0
# 50%      1.000000    0.530436    2.000000   95.123209    0.0   45.0
# 75%      1.000000    0.533433    2.409742   95.123209    0.0   45.0
# max      2.000000    0.578841  103.000000  102.000000    0.0   45.0
#
#              X_5    X_6         X_7         X_8  ...      X_2866     X_2867  \
# count  598.00000  598.0  598.000000  598.000000  ...  598.000000  598.00000
# mean    10.39255    0.0   48.802292   10.048711  ...   50.807300   53.60770
# std      0.37336    0.0    3.339364    0.164586  ...    2.855365    3.31437
# ...

# %%
data = tr.drop(['Y_Class','PRODUCT_ID'], axis =1)
target = tr['Y_Class'].to_numpy()

# 제품에 따른 분류 데이터 생성
# data['PRODUCT_CODE']
a = data[data['PRODUCT_CODE']=='A_31']
t = data[data['PRODUCT_CODE']=='T_31']
o = data[data['PRODUCT_CODE']=='O_31']
# a
a.count()
# Out:
# Y_Quality       249
# TIMESTAMP       249
# LINE            249
# PRODUCT_CODE    249
# X_1             249
#                ...
# X_2871          249
# X_2872            0
# X_2873            0
# X_2874            0
# X_2875            0
# Length: 2879, dtype: int64

# %%
# 제품에 따른 불량개수

# tr_sum = tr[["PRODUCT_CODE", 'Y_Class']].groupby("PRODUCT_CODE").sum()
# tr_sum = tr_sum.reset_index() #컬럼명없이... 인덱스가 초기화됨
# display(tr_sum)

# acount = tr[(tr['Y_Class']==1)&(tr['PRODUCT_CODE']=='A_31')]["PRODUCT_ID"].count()
# tcount=tr[(tr['Y_Class']==1)&(tr['PRODUCT_CODE']=='T_31')]["PRODUCT_ID"].count()
# ocount =tr[(tr['Y_Class']==1)&(tr['PRODUCT_CODE']=='O_31')]["PRODUCT_ID"].count()

ttrr = tr[['Y_Class','PRODUCT_CODE']]
# print(ttrr)
ttrr = ttrr[ttrr['Y_Class']==1].groupby("PRODUCT_CODE").sum()
ttrr = ttrr.reset_index()
# print(ttrr["PRODUCT_CODE"])
ttrr
# Out:
#   PRODUCT_CODE  Y_Class
# 0         A_31      118
# 1         O_31        4
# 2         T_31      285

# %%
ttrr[ttrr['Y_Class']==1].groupby("PRODUCT_CODE").sum().plot.bar();
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/js/792bsrvx24lcg4nrdgy7k5br0000gn/T/ipykernel_994/3749710081.py in <module>
# ----> 1 ttrr[ttrr['Y_Class']==1].groupby("PRODUCT_CODE").sum().plot.bar();
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1129         other axis represents a measured value.
#    1130         """
# -> 1131         return self(kind="bar", x=x, y=y, **kwargs)
#    1132
#    1133     @Appender(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ...

# %%
product = tr['PRODUCT_CODE'].unique()
product
# Out:
# array(['A_31', 'T_31', 'O_31'], dtype=object)

# %%
# 프로더그 코드별로 구분시켜서 학습시키려고..

atr = tr[tr["PRODUCT_CODE"]=="A_31"]
ttr = tr[tr["PRODUCT_CODE"]=="T_31"]
otr = tr[tr["PRODUCT_CODE"]=="O_31"]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 막대그래프 만들기
sns.barplot(data=ttrr, x="PRODUCT_CODE", y="Y_Class")
plt.title("number of fit_product")
plt.show()

# %%
# x_columns = []
# for i in range(1,2876):
#     x
x_columns
# Out:
# ['X_1',
#  'X_2',
#  'X_3',
#  'X_4',
#  'X_5',
#  'X_6',
#  'X_7',
#  'X_8',
#  'X_9',
#  'X_10',
#  'X_11',
#  'X_12',
#  'X_13',
#  'X_14',
#  'X_15',
#  'X_16',
#  'X_17',
#  'X_18',
#  'X_19',
#  'X_20',
#  'X_21',
#  'X_22',
#  'X_23',
#  'X_24',
#  'X_25',
#  'X_26',
#  'X_27',
#  'X_28',
#  'X_29',
#  'X_30',
#  'X_31',
#  'X_32',
#  'X_33',
#  'X_34',
#  'X_35',
#  'X_36',
#  'X_37',
#  'X_38',
#  'X_39',
#  'X_40',
#  'X_41',
#  'X_42',
#  'X_43',
#  'X_44',
#  'X_45',
#  'X_46',
#  'X_47',
#  'X_48',
#  'X_49',
#  'X_50',
#  'X_51',
#  'X_52',
#  'X_53',
#  'X_54',
#  'X_55',
#  'X_56',
#  'X_57',
#  'X_58',
#  'X_59',
#  'X_60',
#  'X_61',
#  'X_62',
#  'X_63',
#  'X_64',
#  'X_65',
#  'X_66',
#  'X_67',
#  'X_68',
#  'X_69',
#  'X_70',
#  'X_71',
#  'X_72',
#  'X_73',
#  'X_74',
#  'X_75',
#  'X_76',
#  'X_77',
#  'X_78',
#  'X_79',
#  'X_80',
#  'X_81',
#  'X_82',
#  'X_83',
#  'X_84',
#  'X_85',
#  'X_86',
#  'X_87',
#  'X_88',
#  'X_89',
#  'X_90',
#  'X_91',
# ...

# %%
# 일단 이렇게 그래프 그릴 수도 있긴한데.. 약간 쓸모는 없을듯
sns.pairplot(tr, x_vars=["X_1","X_2","X_3"], y_vars=['Y_Class']);

# %%
tr.corr()
# Out:
#             Y_Class  Y_Quality       X_1       X_2  X_3  X_4       X_5  X_6  \
# Y_Class    1.000000   0.813885  0.004189 -0.052453  NaN  NaN -0.052164  NaN
# Y_Quality  0.813885   1.000000 -0.003123 -0.049819  NaN  NaN -0.040299  NaN
# X_1        0.004189  -0.003123  1.000000 -0.009092  NaN  NaN  0.079607  NaN
# X_2       -0.052453  -0.049819 -0.009092  1.000000  NaN  NaN  0.569530  NaN
# X_3             NaN        NaN       NaN       NaN  NaN  NaN       NaN  NaN
# ...             ...        ...       ...       ...  ...  ...       ...  ...
# X_2871          NaN        NaN       NaN       NaN  NaN  NaN       NaN  NaN
# X_2872          NaN        NaN       NaN       NaN  NaN  NaN       NaN  NaN
# X_2873          NaN        NaN       NaN       NaN  NaN  NaN       NaN  NaN
# X_2874          NaN        NaN       NaN       NaN  NaN  NaN       NaN  NaN
# X_2875          NaN        NaN       NaN       NaN  NaN  NaN       NaN  NaN
#
# ...

# %%
# tr
# Out:
#     PRODUCT_ID  Y_Class  Y_Quality         TIMESTAMP     LINE PRODUCT_CODE  \
# 0    TRAIN_000        1   0.533433   2022-06-13 5:14  T050304         A_31
# 1    TRAIN_001        2   0.541819   2022-06-13 5:22  T050307         A_31
# 2    TRAIN_002        1   0.531267   2022-06-13 5:30  T050304         A_31
# 3    TRAIN_003        2   0.537325   2022-06-13 5:39  T050307         A_31
# 4    TRAIN_004        1   0.531590   2022-06-13 5:47  T050304         A_31
# ..         ...      ...        ...               ...      ...          ...
# 593  TRAIN_593        1   0.526546  2022-09-08 14:30  T100306         T_31
# 594  TRAIN_594        0   0.524022  2022-09-08 22:38  T050304         A_31
# 595  TRAIN_595        0   0.521289  2022-09-08 22:47  T050304         A_31
# 596  TRAIN_596        1   0.531375  2022-09-08 14:38  T100304         O_31
# 597  TRAIN_597        1   0.533702  2022-09-08 14:46  T100306         O_31
#
# ...

# %%
# sns.heatmap(tr.corr(), cmap="YlGnBu", annot = True)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/js/792bsrvx24lcg4nrdgy7k5br0000gn/T/ipykernel_2127/3589323644.py in <module>
# ----> 1 sns.heatmap(tr.corr(), cmap="YlGnBu", annot = True)
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551     if square:
#     552         ax.set_aspect("equal")
# --> 553     plotter.plot(ax, cbar_ax, kwargs)
#     554     return ax
# ...

# %% [markdown]
# 여기서부터 러닝..시작..

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
atr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249 entries, 0 to 595
# Columns: 2881 entries, PRODUCT_ID to X_2875
# dtypes: float64(2876), int64(1), object(4)
# memory usage: 5.5+ MB

# %%
X = atr.drop(['Y_Class','PRODUCT_ID','TIMESTAMP','PRODUCT_CODE','LINE'], axis =1)
y = atr['Y_Class'].to_numpy()

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249 entries, 0 to 595
# Columns: 2876 entries, Y_Quality to X_2875
# dtypes: float64(2876)
# memory usage: 5.5 MB

# %%
# Out:
# PRODUCT_ID      0
# Y_Class         0
# Y_Quality       0
# TIMESTAMP       0
# LINE            0
#              ...
# X_2871          0
# X_2872        249
# X_2873        249
# X_2874        249
# X_2875        249
# Length: 2881, dtype: int64

# %%
#트레인은 학습용 데이터, 테스트는 시험보는 데이터
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) #70퍼센트만 돌림(test사이즈를 30프로로...)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/js/792bsrvx24lcg4nrdgy7k5br0000gn/T/ipykernel_994/840897885.py in <module>
#       1 lr = LinearRegression()
# ----> 2 lr.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
#결측치 없음...!
atr.isnull().sum()
# Out:
# PRODUCT_ID      0
# Y_Class         0
# Y_Quality       0
# TIMESTAMP       0
# LINE            0
#              ...
# X_2871          0
# X_2872        249
# X_2873        249
# X_2874        249
# X_2875        249
# Length: 2881, dtype: int64
